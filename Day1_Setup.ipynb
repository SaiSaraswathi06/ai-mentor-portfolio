# %% [markdown]
# <a href="https://colab.research.google.com/github/SaiSaraswathi06/ai-mentor-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os

os.environ["GEMINI_API_KEY"] = "AQ.Ab8RN6K9Fjqh-kptcvtIBWtLrIv9b2I3ZASbPV6cAK0jiq8J_g"

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines a hierarchical progression of AI competencies, from foundational understanding to strategic leadership:
#
# *   **Foundation (Data Fluency & AI Literacy):** It starts with understanding data quality, sources, and basic analytics, combined with grasping AI concepts, capabilities, limitations, and ethical considerations.
# *   **AI Tool Proficiency:** This layer involves practical, hands-on ability to use specific AI tools, platforms, and applications (e.g., ML software, generative AI models) to accomplish tasks.
# *   **AI Solution Architecting:** This involves designing, developing, and integrating AI models and systems into broader business processes or products, requiring problem-solving and technical integration skills.
# *   **AI Strategy & Ethics:** At the apex, this layer focuses on leadership, defining an organization's AI vision, establishing governance, managing ethical risks, and aligning AI initiatives with business goals.
